# %%
import pandas as pd
import numpy as np
import pylab as P
from sklearn.ensemble import RandomForestClassifier 

import matplotlib.pyplot as plt
#%matplotlib inline
plt.close("all")

# %%
# For .read_csv, always use header=0 when you know row 0 is the header row
df = pd.read_csv(r'/home/rahulmanuwas/Dropbox/Kaggle/train.csv', header=0)
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic = df
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#Replace all the missing values in the Age column of titanic
titanic["Age"] = titanic["Age"].fillna(titanic["Age"].median())
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
# Find all the unique genders -- the column appears to contain only male and female.
print(titanic["Sex"].unique())
# Out:
# ['male' 'female']

# %%
# Replace all the occurences of male with the number 0 and female with 1.
titanic.loc[titanic["Sex"] == "male", "Sex"] = 0
titanic.loc[titanic["Sex"] == "female", "Sex"] = 1

titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#     Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic["Fare"] = titanic["Fare"].fillna(titanic["Fare"].median())

# %%
titanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#     Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic["Pclass"] = titanic["Pclass"].fillna(np.random.choice(range(2, 4))) #Insert 2/3 randomly in class
print titanic[["PassengerId","Pclass", "Fare", "Sex", "Survived"]].tail(10)
#titanic.dtypes
# Out:
#      PassengerId  Pclass     Fare Sex  Survived
# 881          882       3   7.8958   0         0
# 882          883       3  10.5167   1         0
# 883          884       2  10.5000   0         0
# 884          885       3   7.0500   0         0
# 885          886       3  29.1250   1         0
# 886          887       2  13.0000   0         0
# 887          888       1  30.0000   1         1
# 888          889       3  23.4500   1         0
# 889          890       1  30.0000   0         1
# 890          891       3   7.7500   0         0

# %%
# customer_group = customers.groupby('name')
# customer_group.size()
# sales_totals = customer_group.sum()
# sales_totals.sort(columns='ext price').head()
# my_plot = sales_totals.plot(kind='bar')

# %%
titanic2 = titanic[["Name", "Pclass", "Fare", "Sex", "Survived"]] #"PassengerId",
titanic_group = titanic2.groupby("Name")
titanic_group.size()
fares_totals = titanic_group["Fare"].sum()
fares_totals.sort_index(ascending=True)
fares_totals.head(5)
# Out:
# Name
# Abbing, Mr. Anthony                       7.55
# Abbott, Mr. Rossmore Edward              20.25
# Abbott, Mrs. Stanton (Rosa Hunt)         20.25
# Abelson, Mr. Samuel                      24.00
# Abelson, Mrs. Samuel (Hannah Wizosky)    24.00
# Name: Fare, dtype: float64

# %%
#myplot = titanic_group.plot(kind="hist",stacked=True, figsize=(29, 30))
# plt.plot(titanic["PassengerId"], titanic["Survived"]*50)
# plt.plot(titanic["PassengerId"], titanic["Fare"])
# axes = plt.axes()
# axes.set_xlim([-1, 900])
# axes.set_ylim([0, 100])
#plt.show()

# %%
bins = [0, 10, 20, 30, 10000]
ticket_prices = ['0$', '10$', '20$', '30$']
categories = pd.cut(titanic["Fare"], bins, labels= ticket_prices)

# %%
titanic["bin_categories"] = pd.cut(titanic['Fare'], bins, labels=prices)
titanic["bin_categories"]
pd.value_counts(titanic["bin_categories"])
# Out:
# 10$    321
# 40$    234
# 20$    179
# 30$    142
# dtype: int64

# %%
pd.value_counts(titanic["Sex"])
# Out:
# 0    577
# 1    314
# Name: Sex, dtype: int64

# %%
titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked bin_categories
# 0         A/5 21171   7.2500   NaN        S            10$
# 1          PC 17599  71.2833   C85        C            40$
# 2  STON/O2. 3101282   7.9250   NaN        S            10$
# 3            113803  53.1000  C123        S            40$
# ...

# %%
df_total = titanic.groupby('bin_categories').count()
print df_total
print df_total["Survived"].count()
# df_survived = titanic[titanic['Survived']==1].groupby('bin_categories').count()
# print df_survived
#result = pd.merge(df_total, df_survived, on=df_survived['bin_categories'])
# Out:
#                 PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  \
# bin_categories
# 10$                     321       321     321   321  321  321    321    321
# 20$                     179       179     179   179  179  179    179    179
# 30$                     142       142     142   142  142  142    142    142
# 40$                     234       234     234   234  234  234    234    234
#
#                 Ticket  Fare  Cabin  Embarked
# bin_categories
# 10$                321   321      6       321
# 20$                179   179     17       179
# 30$                142   142     33       142
# 40$                234   234    145       232
# 4

# %%
print (321+179+142+234)
print (66+76+63+136)

# %%
#df_survived_percent = df_survived.groupby('bin_categories').count()['Survived']/titanic.groupby('bin_categories').count()["Survived"]

# %%
#df_survived_percent
